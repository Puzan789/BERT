# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pip install transformers
# !pip install datasets

# %%
import operator
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datasets import load_dataset
from tensorflow import keras 
from transformers import AutoTokenizer
from transformers import pipeline
from transformers import TFAutoModelForQuestionAnswering

# %%
classifier=pipeline("text-classification")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
classifier("allice is beautiful")
classifier("what the fuck dude  lets go again there to watch them fighting FOR ufc")
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9355406761169434}]

# %%
summarizer=pipeline("summarization")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]

# %%
text='''Albert Einstein, born on March 14, 1879, in Ulm, Germany, was a theoretical physicist whose groundbreaking contributions revolutionized our understanding of the universe. Renowned for his theory of relativity, Einstein's work reshaped the foundations of physics and earned him the Nobel Prize in Physics in 1921.

Einstein's early years were marked by an inquisitive mind and a rebellious spirit. He struggled within the confines of traditional education, often questioning authority and formalities. However, his passion for physics prevailed, leading him to the Swiss Federal Institute of Technology (ETH Zurich), where he earned a teaching diploma in 1900.

In 1905, Einstein published four groundbreaking papers that would alter the course of modern physics. Among them was the photoelectric effect paper, which proposed that light could be both a wave and a particle, laying the foundation for quantum theory. His most famous equation, E=mc^2, emerged from his theory of special relativity, demonstrating the equivalence of energy (E) and mass (m).

Einstein's theory of general relativity, published in 1915, presented a new understanding of gravity, describing it as the curvature of space-time caused by mass. This theory successfully predicted phenomena like the bending of light around massive objects, affirming its accuracy.

Fleeing Nazi persecution, Einstein emigrated to the United States in 1933, where he joined the Institute for Advanced Study in Princeton. Despite facing challenges adapting to American culture, he continued his scientific pursuits, collaborating with other brilliant minds.

An advocate for pacifism, civil rights, and Zionism, Einstein used his platform to address broader societal issues. He spoke out against nuclear weapons during World War II and later became a prominent figure in the anti-nuclear weapons movement.

Einstein's intellect and wit made him a celebrated public figure. His iconic tousled hair, patent office days, and the escapades with his violin became part of his legend. Even in popular culture, the name Einstein has become synonymous with genius.

Albert Einstein's legacy extends far beyond the realm of physics. His work not only revolutionized science but also impacted philosophy, culture, and our understanding of the interconnectedness of space and time. Einstein passed away on April 18, 1955, but his ideas and influence continue to shape the scientific landscape, inspiring generations of physicists and thinkers worldwide.'''

# %%
summarizer(text)
# Out:
# [{'summary_text': ' Albert Einstein was a theoretical physicist whose groundbreaking contributions revolutionized our understanding of the universe . His theory of general relativity, published in 1915, presented a new understanding of gravity . His work not only revolutionized science but also impacted philosophy, culture and philosophy . He passed away on April 18, 1955, but his ideas and influence continue to shape the scientific landscape .'}]

# %%
qa=pipeline("question-answering")
# Out:
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]

# %%
question="what did he spoke against? and when did he died?"
qa(question=question,context=text)
# Out:
# {'score': 0.7530422806739807,
#  'start': 1750,
#  'end': 1765,
#  'answer': 'nuclear weapons'}

# %% [markdown]
# # For name entity recognition

# %%
ner=pipeline(model="dslim/bert-base-NER")
# Out:
# config.json:   0%|          | 0.00/829 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/433M [00:00<?, ?B/s]
# Some weights of the model checkpoint at dslim/bert-base-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/59.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# ...

# %%
ner(text)[0]
# Out:
# {'entity': 'B-PER',
#  'score': 0.99935275,
#  'index': 1,
#  'word': 'Albert',
#  'start': 0,
#  'end': 6}
